# %% [markdown]
# <h1><b>Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# <h1><b>Go to work directive

# %%
import os
# !pwd
# !ls
os.chdir('drive/My Drive/yolov3')
# !pwd
# Out:
# /content
# drive  sample_data
# /content/drive/My Drive/yolov3

# %% [markdown]
# <h1><b>Model Training

# %% [markdown]
# <b>Batch size = 16 <br>
# learning_rate = 0.1 </b>

# %%
# !python train_lr01.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.1.cfg --weights yolov3-tiny.weights --batch-size 16 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.1.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 15:05:25.040712: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1052.73it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1249.41it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 16 <br>
# learning_rate = 0.01 </b>

# %%
# !python train_lr001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.01.cfg --weights yolov3-tiny.weights --batch-size 16 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.01.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 15:08:05.282332: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1222.45it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1233.70it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 16 <br>
# learning_rate = 0.001 </b>

# %%
# !python train_lr0001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.001.cfg --weights yolov3-tiny.weights --batch-size 16 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.001.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 16:02:59.391915: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1244.29it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1391.21it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 16 <br>
# learning_rate = 0.0001 </b>

# %%
# !python train_lr00001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.0001.cfg --weights yolov3-tiny.weights --batch-size 16 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.0001.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 17:17:10.715514: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1231.46it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1271.11it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 32 <br>
# learning_rate = 0.1</b>

# %%
# !python train_lr01.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.1.cfg --weights yolov3-tiny.weights --batch-size 32 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=32, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.1.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 18:09:02.625681: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1220.32it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1413.99it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 32 <br>
# learning_rate = 0.01 </b>

# %%
# !python train_lr001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.01.cfg --weights yolov3-tiny.weights --batch-size 32 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=32, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.01.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 18:09:41.272956: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1109.65it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1250.88it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 32 <br>
# learning_rate = 0.001</b>

# %%
# !python train_lr0001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.001.cfg --weights yolov3-tiny.weights --batch-size 32 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=32, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.001.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-29 15:33:45.487972: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [04:56<00:00,  3.55it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:39<00:00,  3.83it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 32 <br>
# learning_rate = 0.0001</b>

# %%
# !python train_lr00001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.0001.cfg --weights yolov3-tiny.weights --batch-size 32 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=32, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.0001.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-29 00:20:04.729179: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1181.54it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1276.07it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 64 <br>
# learning_rate = 0.1</b>

# %%
# !python train_lr01.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.1.cfg --weights yolov3-tiny.weights --batch-size 64 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=64, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.1.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-23 00:32:14.447883: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:01<00:00, 854.39it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 938.59it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 64 <br>
# learning_rate = 0.01

# %%
# !python train_lr001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.01.cfg --weights yolov3-tiny.weights --batch-size 64 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=64, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.01.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-29 01:21:14.977998: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1066.91it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1047.62it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 64 <br>
# learning_rate = 0.001

# %%
# !python train_lr0001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.001.cfg --weights yolov3-tiny.weights --batch-size 64 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=64, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.001.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-29 16:43:56.751176: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:01<00:00, 852.86it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1004.72it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 64 <br>
# learning_rate = 0.0001

# %%
# !python train_lr00001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.0001.cfg --weights yolov3-tiny.weights --batch-size 64 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=64, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.0001.cfg', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-29 03:20:54.526975: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1214.57it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1342.39it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 128<br>
# learning_rate = 0.1 </b>

# %%
# !python train_lr01.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.1 --weights yolov3-tiny.weights --batch-size 128 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=128, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.1', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-23 17:11:34.199688: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [05:30<00:00,  3.18it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:38<00:00,  3.88it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 128<br>
# learning_rate = 0.01 </b>

# %%
# !python train_lr001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.01 --weights yolov3-tiny.weights --batch-size 128 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=128, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.01', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 20:06:26.723582: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1266.16it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1229.52it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 128<br>
# learning_rate = 0.001 </b>

# %%
# !python train_lr0001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.001 --weights yolov3-tiny.weights --batch-size 128 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=128, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.001', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 21:06:22.292740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1223.13it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1279.75it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# <b>Batch size = 128<br>
# learning_rate = 0.0001 </b>

# %%
# !python train_lr00001.py --data data/coin_data.data --cfg mycfg/yolov3-tiny-lr\=0.0001 --weights yolov3-tiny.weights --batch-size 128 --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=128, bucket='', cache_images=False, cfg='mycfg/yolov3-tiny-lr=0.0001', data='data/coin_data.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, var=None, weights='yolov3-tiny.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-28 22:11:28.118215: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# Caching labels (1051 found, 0 missing, 0 empty, 0 duplicate, for 1051 images): 100% 1051/1051 [00:00<00:00, 1202.44it/s]
# Caching labels (151 found, 0 missing, 0 empty, 0 duplicate, for 151 images): 100% 151/151 [00:00<00:00, 1202.68it/s]
# Using 4 dataloader workers
# Starting training for 100 epochs...
#
# ...

# %% [markdown]
# **Inference**
# - On video

# %%
# !python detect.py --cfg mycfg/yolov3-tiny-lr00001bs16.cfg --weights results/temp/lr00001bs16.pt --names ../coin/classes.names --source ../video/coins.mp4
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# video 1/1 (1138/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1139/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1140/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1141/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1142/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1143/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.002s)
# video 1/1 (1144/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1145/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1146/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.003s)
# video 1/1 (1147/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.002s)
# video 1/1 (1148/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.002s)
# video 1/1 (1149/6134) ../video/coins.mp4: 256x416 3 coins, Done. (0.002s)
# ...

# %% [markdown]
# - Real time camera

# %%
# !python detect.py --cfg mycfg/yolov3-tiny-lr00001bs16.cfg --weights results/temp/lr00001bs16.pt --names ../coin/classes.names --source 0
# Out:
# Namespace(agnostic_nms=False, cfg='mycfg/yolov3-tiny-lr00001bs16.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=416, iou_thres=0.6, names='../coin/classes.names', output='output', save_txt=False, source='0', view_img=False, weights='results/temp/lr00001bs16.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 37 layers, 8.66988e+06 parameters, 8.66988e+06 gradients
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0
# 1/1: 0... Traceback (most recent call last):
#   File "detect.py", line 179, in <module>
#     detect()
#   File "detect.py", line 67, in detect
#     dataset = LoadStreams(source, img_size=img_size)
#   File "/content/drive/My Drive/Colab Notebooks/yolov3/utils/datasets.py", line 203, in __init__
#     assert cap.isOpened(), 'Failed to open %s' % s
# AssertionError: Failed to open 0
